# %%
#1. Explain the different types of data (qualitative and quantitative) and provide examples of each. Discuss nominal, ordinal, interval, and ratio scales.
# answer-->Qualitative Data
#Qualitative data, also known as categorical data, refers to non-numeric information that describes characteristics or qualities. It can be further divided into:

#Nominal Data: This type of data represents categories without any intrinsic ordering. Examples include:

#Gender (male, female, non-binary)
#Colors (red, blue, green)
#Types of cuisine (Italian, Mexican, Indian)
#Ordinal Data: This type represents categories with a meaningful order but no fixed interval between them. Examples include:

#Survey ratings (poor, fair, good, excellent)
#Education level (high school, bachelor's, master's, doctorate)
#Class rankings (1st, 2nd, 3rd)
#Quantitative Data
#Quantitative data refers to numerical information that can be measured or counted. It can also be divided into:

#Interval Data: This type of data has meaningful intervals between values but lacks a true zero point. Examples include:

#Temperature (Celsius or Fahrenheit)
#Dates (years, like 1990, 2000, 2010)
#Ratio Data: This type possesses all the properties of interval data, but it also has a true zero, allowing for meaningful comparisons and calculations. Examples include:

#Weight (0 kg means no weight)
#Height (0 cm means no height)
#Income (0 dollars means no income)

# %%
#2. What are the measures of central tendency, and when should you use each? Discuss the mean, median, and mode with examples and situations where each is appropriate.
#answer-->1. Mean
#The mean is the average of all values in a dataset. It is calculated by summing all the values and dividing by the number of values.

#Example:
#Consider the test scores: 80, 85, 90, 95, and 100.
#Mean = (80 + 85 + 90 + 95 + 100) / 5 = 90.

#Appropriate Use:

#When the data is normally distributed (symmetrical).
#When you want to consider all data points.
#However, be cautious with outliers, as they can skew the mean.
#2. Median
#The median is the middle value in a dataset when it is ordered from least to greatest. If there is an even number of values, the median is the average of the two middle values.

#Example:
#For the scores 80, 85, 90, 95, and 100, the median is 90 (the third score).
#For the scores 80, 85, 90, and 95, the median is (85 + 90) / 2 = 87.5.

#Appropriate Use:

#When the data is skewed or has outliers.
#It better represents the central tendency in such cases, as it is not affected by extreme values.
#3. Mode
#The mode is the value that appears most frequently in a dataset.

#Example:
#In the dataset 1, 2, 2, 3, 4, the mode is 2.
#In a dataset where all values are unique (e.g., 1, 2, 3, 4), there is no mode.

#Appropriate Use:

#When dealing with categorical data where you want to identify the most common category.
#When the data is multimodal (more than one mode), providing insights into the distribution.

# %%
#3. Explain the concept of dispersion. How do variance and standard deviation measure the spread of data?
#answer-->Dispersion refers to the extent to which data values in a dataset differ from one another and from the central tendency (mean, median, or mode). It provides insight into the variability or spread of the data, indicating how much the data points deviate from the average value. Two key measures of dispersion are variance and standard deviation.

#1. Variance
#Variance quantifies the degree of spread in the data. It measures the average squared deviation of each data point from the mean. A higher variance indicates that the data points are more spread out, while a lower variance suggests they are closer to the mean.



#Example: For the dataset: 4, 8, 6, 5, and 3:#

#Mean = (4 + 8 + 6 + 5 + 3) / 5 = 5.2
#Variance = [(4-5.2)² + (8-5.2)² + (6-5.2)² + (5-5.2)² + (3-5.2)²] / 5
#Variance = [(1.44 + 7.84 + 0.64 + 0.04 + 4.84) / 5] = 2.96
#2. Standard Deviation
#Standard deviation is the square root of the variance. It is expressed in the same units as the original data, making it more interpretable. Standard deviation provides a more direct sense of how much data points typically deviate from the mean.



#Example: Continuing from the previous variance example:

#Standard Deviation = √2.96 ≈ 1.72
#Importance of Variance and Standard Deviation
#Variance is useful in statistical modeling and when comparing datasets because it considers all data points. However, its squared units can make it less intuitive.
#Standard Deviation is often preferred for reporting because it is in the same units as the original data, making it easier to understand the typical deviation from the mean.

# %%
#4. What is a box plot, and what can it tell you about the distribution of data?
#answer-->A box plot (or whisker plot) is a graphical representation of a dataset that summarizes its central tendency, variability, and overall distribution. It provides a visual overview of the data's distribution through its quartiles and highlights potential outliers.

#Components of a Box Plot
#Box: Represents the interquartile range (IQR), which contains the middle 50% of the data. The box is formed by:

#Lower Quartile (Q1): The 25th percentile, marking the first edge of the box.
#Upper Quartile (Q3): The 75th percentile, marking the second edge of the box.
#Median (Q2): The line inside the box represents the median of the data.
#Whiskers: Extend from the edges of the box to the minimum and maximum values within a defined range (usually 1.5 times the IQR). They help visualize the spread of the data outside the quartiles.

#Outliers: Data points that fall outside the whiskers are considered outliers. They are typically marked with individual points or asterisks.

# %%
#5. Discuss the role of random sampling in making inferences about populations.
#answer-->Random sampling is essential for making inferences about populations because it ensures that every individual has an equal chance of being selected, leading to a representative sample. This approach helps reduce bias, allows for generalization of findings, and supports the validity of statistical analyses. It also enables researchers to estimate sampling error and apply more advanced statistical techniques. By using random sampling, conclusions drawn from a sample can confidently be extended to the larger population.

# %%
#6. Explain the concept of skewness and its types. How does skewness affect the interpretation of data?
#answer-->skewnees is the concept to measurement of the symmetritcity
#1-No skwenees-totally symmetric,where skewenees is 0,mean=median=mode
#2-positve skewed data--most of the distribution of the data is lies on right side,tail is at the right side,mean>=median>=mode
#3-negative skewed data--most of the distribution of the data is lis in the left side ,tail is at the left side,mode>=median>=mean

# %%
#7. What is the interquartile range (IQR), and how is it used to detect outliers?
#answer-->Inter qurtile range is the range where we can detect the outliers,it is used to detect the outliers
#since IQR deals wiht Q3 and Q1 this is not effected by outliers
#outliers is detected as Lower fense= Q1-1.5*IQR
#                        Upper fense= Q3+1.5*IQR

# %%
#8. Discuss the conditions under which the binomial distribution is used.
#answer-->The binomial distribution is used under the following conditions:

#Fixed Number of Trials: The experiment consists of a predetermined number of trials (n).

#Two Possible Outcomes: Each trial results in one of two outcomes, typically referred to as "success" and "failure."

#Constant Probability: The probability of success (p) remains the same for each trial.

#Independent Trials: The outcome of one trial does not affect the outcome of another.

# %%
#9. Explain the properties of the normal distribution and the empirical rule (68-95-99.7 rule).
#answer-->Properties of the Normal Distribution
#Symmetry: The normal distribution is symmetric around its mean, meaning the left and right sides are mirror images.
#Bell-Shaped Curve: It has a characteristic bell shape, with most data points clustering around the mean.
#Mean, Median, Mode: In a normal distribution, these three measures of central tendency are all equal.
#Asymptotic: The tails of the distribution approach the horizontal axis but never touch it.
#Defined by Mean and Standard Deviation: The shape of the distribution is determined by its mean (center) and standard deviation (spread).
#Empirical Rule (68-95-99.7 Rule)
#This rule describes the percentage of data that falls within certain standard deviations of the mean in a normal distribution:

#68% of the data falls within ±1 standard deviation of the mean.
#95% of the data falls within ±2 standard deviations of the mean.
#99.7% of the data falls within ±3 standard deviations of the mean.

# %%
#11. Explain what a random variable is and differentiate between discrete and continuous random variables.
#answer-->A random variable is a numerical outcome of a random phenomenon. It assigns a numerical value to each outcome in a sample space.

#Types of Random Variables
#Discrete Random Variables: These take on a countable number of distinct values. Examples include:

#The number of heads in 10 coin flips.
#The number of students in a classroom.
#Continuous Random Variables: These can take on an infinite number of values within a given range. Examples include:

#The height of students.
#The time it takes to complete a task.

# %%
#12. Provide an example dataset, calculate both covariance and correlation, and interpret the results
import seaborn as sns
import pandas as pd
df=sns.load_dataset('tips')
df.head()
#covariance
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.cov(numeric_only=True)
#The range is fron the -infinity to +infinity,it has any value
# Out:
#             total_bill       tip      size
# total_bill   79.252939  8.323502  5.065983
# tip           8.323502  1.914455  0.643906
# size          5.065983  0.643906  0.904591

# %%
df.corr(numeric_only=True)
#correlation
#it has a range of -1 to +1,it gives the most accurate relationship between the two features
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000
